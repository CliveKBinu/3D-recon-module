# %%
from recon import *

# %%
files = load_images('F:/Research/annotated_tomograms/lead_gap_constrained_none_*.png')

# %%
# %matplotlib inline
Reconstrcution(files)
# Out:
# best z_plane=57
# Running inference for F:/Research/annotated_tomograms\lead_gap_constrained_none_img57.png... Loading model...Done! Took 42.59103322029114 seconds
# Detected_number_of_objects:2
# best z_plane=57
# Finished Segmenting image
# Getting Corrdinatees
# Done Getting Corrdinatees
# Finished Plotting
